# %%
import sklearn
import os
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-78257881e09c> in <module>
# ----> 1 import sklearn
#       2 import os
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip3 list
# Out:
# Package             Version
# ------------------- -------
# argon2-cffi         20.1.0
# async-generator     1.10
# attrs               20.3.0
# backcall            0.2.0
# bleach              3.2.1
# cffi                1.14.4
# cycler              0.10.0
# decorator           4.4.2
# defusedxml          0.6.0
# entrypoints         0.3
# ipykernel           5.4.2
# ipython             7.19.0
# ipython-genutils    0.2.0
# ipywidgets          7.6.2
# jedi                0.18.0
# Jinja2              2.11.2
# jsonschema          3.2.0
# jupyter             1.0.0
# jupyter-client      6.1.7
# jupyter-console     6.2.0
# jupyter-core        4.7.0
# jupyterlab-pygments 0.1.2
# jupyterlab-widgets  1.0.0
# kiwisolver          1.3.1
# MarkupSafe          1.1.1
# matplotlib          3.3.3
# mistune             0.8.4
# nbclient            0.5.1
# nbconvert           6.0.7
# nbformat            5.0.8
# nest-asyncio        1.4.3
# notebook            6.1.6
# numpy               1.19.5
# ...
